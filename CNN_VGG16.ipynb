# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input, VGG16, decode_predictions

# %%
image = load_img("dog.jpg", target_size=(224, 224))

# %%
plt.imshow(image)

# %%
image = img_to_array(image)
image = image.reshape((1, 224, 224, 3))
image = preprocess_input(image)

# %%
model = VGG16()
pred = model.predict(image)

# %%
decode_predictions(pred)
# Out:
# [[('n02099601', 'golden_retriever', 0.8177133),
#   ('n02099712', 'Labrador_retriever', 0.1208045),
#   ('n02104029', 'kuvasz', 0.026199184),
#   ('n02111500', 'Great_Pyrenees', 0.019839332),
#   ('n02100735', 'English_setter', 0.0021371946)]]
